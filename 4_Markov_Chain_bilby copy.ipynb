# %%
DIR = "norms"

import os
import bilby

import numpy as np

from glob import glob
from scipy import stats
from likelihood import Likelihood

# Restrict processes to one thread only
os.environ['OMP_NUM_THREADS'] = '1'

# emcee variables
nsteps = 10000 # How many steps should each walker take?
nthin  = 10    # How often should the walker save a step?
nprocs = 6     # How many Python processes do you want to allocate?

# Define the data labels (in AZURE2 order)
labels = ["Meyer et al. (1976) - 84.3 deg",
          "Meyer et al. (1976) - 114.5 deg",
          "Meyer et al. (1976) - 144.1 deg", 
          "LUNA HPGe (2023)", 
          "LUNA BGO (2023)",
          "Felsenkeller (2023)",
          "ATOMKI (2023)",
          "Notre Dame (2023) - 0 deg",
          "Notre Dame (2023) - 55 deg",
          "Burtebaev et al. (2008)",
          "Lamb et al. (1957)",
          "Bailey et al. (1950)",
          "Vogl et al. (1963)",
          "Rolfs et al. (1974) - 0 deg",
          "Rolfs et al. (1974) - 90 deg"]

# Define the parameters prior distributions
priors = dict(
    param_0=bilby.core.prior.Gaussian(1.63, 0.12, "param_0"),

    param_1=bilby.core.prior.Uniform(2.30, 2.410, "param_1"), 
    param_2=bilby.core.prior.Uniform(3e4, 4e4, "param_2"), 
    param_3=bilby.core.prior.Uniform(-5, 0, "param_3"),
    param_4=bilby.core.prior.Uniform(-1e4, 2e4, "param_4"),

    param_5=bilby.core.prior.Uniform(3.45, 3.55, "param_5"), 
    param_6=bilby.core.prior.Uniform(5e4, 6e4, "param_6"), 
    param_7=bilby.core.prior.Uniform(-5, 0, "param_7"), 
    param_8=bilby.core.prior.Uniform(-0.1, 0.1, "param_8"),
    param_9=bilby.core.prior.Uniform(-1e5, 0, "param_9"), 
    param_10=bilby.core.prior.Uniform(-1e4, 1e5, "param_10"),

    param_11=bilby.core.prior.Uniform(3.50, 3.60, "param_11"), 
    param_12=bilby.core.prior.Uniform(4e4, 6e4, "param_12"),
    
    param_13=bilby.core.prior.LogNormal(0, 0.05, "param_13"),
    param_14=bilby.core.prior.LogNormal(0, 0.05, "param_14"),
    param_15=bilby.core.prior.LogNormal(0, 0.05, "param_15"),
    param_16=bilby.core.prior.LogNormal(0, 0.069, "param_16"),
    param_17=bilby.core.prior.LogNormal(0, 0.079, "param_17"),
    param_18=bilby.core.prior.LogNormal(0, 0.10, "param_18"),
    param_19=bilby.core.prior.LogNormal(0, 0.10, "param_19"),
    param_20=bilby.core.prior.LogNormal(0, 0.10, "param_20"),
    param_21=bilby.core.prior.LogNormal(0, 0.10, "param_21"),
    param_22=bilby.core.prior.LogNormal(0, 0.10, "param_22"),
    param_23=bilby.core.prior.Uniform(0, 10, "param_23"),
    param_24=bilby.core.prior.Uniform(0, 10, "param_24"),
    param_25=bilby.core.prior.Uniform(0, 10, "param_25"),
    param_26=bilby.core.prior.Uniform(0, 10, "param_26"),
    param_27=bilby.core.prior.Uniform(0, 10, "param_27")
)

# %%
# Preparing initial parameters for the walkers
data = []
files = glob( "results/{}/samples_*.txt".format(DIR) )
for file in files:
    data.append( np.loadtxt( file ) )
data = np.concatenate( data, axis=0 )

mean = np.mean( data, axis=0 )

nt = 5
nw = 2 * len(priors)
p0 = np.zeros( (nt, nw, len(priors)) )
for t in range(nt):
    for i in range(nw):
        for j in range(len(priors)):
            if( j not in [1, 5, 11] ): p0[t,i,j] = np.sign(mean[j]) * stats.uniform( abs(mean[j]) * 0.6, abs(mean[j]) * 0.8 ).rvs()
            else: p0[t,i,j] = np.sign(mean[j]) * stats.uniform( abs(mean[j]) * 0.99, abs(mean[j]) * 0.02 ).rvs()

# %%
likelihood = Likelihood( "12c_pg.azr", nprocs=nprocs)

result = bilby.run_sampler( likelihood=likelihood, priors=priors, sampler="ptemcee", outdir="results/bilby/", label="samples", npool=nprocs, pos0=p0, nsteps=nsteps, nthin=nthin, nwalkers=nw, ntemps=nt)
# Out:
# 21:16 bilby INFO    : Running for label 'samples', output will be saved to 'results/bilby/'
# 21:16 bilby INFO    : Analysis priors:
# 21:16 bilby INFO    : param_0=Gaussian(mu=1.63, sigma=0.12, name='param_0', latex_label='param_0', unit=None, boundary=None)
# 21:16 bilby INFO    : param_1=Uniform(minimum=2.3, maximum=2.41, name='param_1', latex_label='param_1', unit=None, boundary=None)
# 21:16 bilby INFO    : param_2=Uniform(minimum=30000.0, maximum=40000.0, name='param_2', latex_label='param_2', unit=None, boundary=None)
# 21:16 bilby INFO    : param_3=Uniform(minimum=-5, maximum=0, name='param_3', latex_label='param_3', unit=None, boundary=None)
# 21:16 bilby INFO    : param_4=Uniform(minimum=-10000.0, maximum=20000.0, name='param_4', latex_label='param_4', unit=None, boundary=None)
# 21:16 bilby INFO    : param_5=Uniform(minimum=3.45, maximum=3.55, name='param_5', latex_label='param_5', unit=None, boundary=None)
# 21:16 bilby INFO    : param_6=Uniform(minimum=50000.0, maximum=60000.0, name='param_6', latex_label='param_6', unit=None, boundary=None)
# 21:16 bilby INFO    : param_7=Uniform(minimum=-5, maximum=0, name='param_7', latex_label='param_7', unit=None, boundary=None)
# 21:16 bilby INFO    : param_8=Uniform(minimum=-0.1, maximum=0.1, name='param_8', latex_label='param_8', unit=None, boundary=None)
# 21:16 bilby INFO    : param_9=Uniform(minimum=-100000.0, maximum=0, name='param_9', latex_label='param_9', unit=None, boundary=None)
# 21:16 bilby INFO    : param_10=Uniform(minimum=-10000.0, maximum=100000.0, name='param_10', latex_label='param_10', unit=None, boundary=None)
# 21:16 bilby INFO    : param_11=Uniform(minimum=3.5, maximum=3.6, name='param_11', latex_label='param_11', unit=None, boundary=None)
# 21:16 bilby INFO    : param_12=Uniform(minimum=40000.0, maximum=60000.0, name='param_12', latex_label='param_12', unit=None, boundary=None)
# 21:16 bilby INFO    : param_13=LogNormal(mu=0, sigma=0.05, name='param_13', latex_label='param_13', unit=None, boundary=None)
# 21:16 bilby INFO    : param_14=LogNormal(mu=0, sigma=0.05, name='param_14', latex_label='param_14', unit=None, boundary=None)
# 21:16 bilby INFO    : param_15=LogNormal(mu=0, sigma=0.05, name='param_15', latex_label='param_15', unit=None, boundary=None)
# 21:16 bilby INFO    : param_16=LogNormal(mu=0, sigma=0.069, name='param_16', latex_label='param_16', unit=None, boundary=None)
# 21:16 bilby INFO    : param_17=LogNormal(mu=0, sigma=0.079, name='param_17', latex_label='param_17', unit=None, boundary=None)
# 21:16 bilby INFO    : param_18=LogNormal(mu=0, sigma=0.1, name='param_18', latex_label='param_18', unit=None, boundary=None)
# 21:16 bilby INFO    : param_19=LogNormal(mu=0, sigma=0.1, name='param_19', latex_label='param_19', unit=None, boundary=None)
# 21:16 bilby INFO    : param_20=LogNormal(mu=0, sigma=0.1, name='param_20', latex_label='param_20', unit=None, boundary=None)
# 21:16 bilby INFO    : param_21=LogNormal(mu=0, sigma=0.1, name='param_21', latex_label='param_21', unit=None, boundary=None)
# 21:16 bilby INFO    : param_22=LogNormal(mu=0, sigma=0.1, name='param_22', latex_label='param_22', unit=None, boundary=None)
# 21:16 bilby INFO    : param_23=Uniform(minimum=0, maximum=10, name='param_23', latex_label='param_23', unit=None, boundary=None)
# 21:16 bilby INFO    : param_24=Uniform(minimum=0, maximum=10, name='param_24', latex_label='param_24', unit=None, boundary=None)
# 21:16 bilby INFO    : param_25=Uniform(minimum=0, maximum=10, name='param_25', latex_label='param_25', unit=None, boundary=None)
# 21:16 bilby INFO    : param_26=Uniform(minimum=0, maximum=10, name='param_26', latex_label='param_26', unit=None, boundary=None)
# 21:16 bilby INFO    : param_27=Uniform(minimum=0, maximum=10, name='param_27', latex_label='param_27', unit=None, boundary=None)
# 21:16 bilby INFO    : Analysis likelihood class: <class 'likelihood.Likelihood'>
# 21:16 bilby INFO    : Analysis likelihood noise evidence: nan
# 21:16 bilby INFO    : Single likelihood evaluation took 5.048e-02 s
# 21:16 bilby WARNING : Supplied argument 'nsteps' not an argument of 'Ptemcee', removing.
# 21:16 bilby WARNING : Supplied argument 'nthin' not an argument of 'Ptemcee', removing.
# 21:16 bilby INFO    : Using sampler Ptemcee with kwargs {'ntemps': 5, 'nwalkers': 56, 'Tmax': None, 'betas': None, 'a': 2.0, 'adaptation_lag': 10000, 'adaptation_time': 100, 'random': None, 'adapt': False, 'swap_ratios': False}
# 21:16 bilby INFO    : Using convergence inputs: ConvergenceInputs(autocorr_c=5, autocorr_tol=50, autocorr_tau=1, gradient_tau=0.1, gradient_mean_log_posterior=0.1, Q_tol=1.02, safety=1, burn_in_nact=50, burn_in_fixed_discard=0, mean_logl_frac=0.01, thin_by_nact=0.5, nsamples=5000, ignore_keys_for_tau=None, min_tau=1, niterations_per_check=5)
# 21:16 bilby INFO    : Setting up multiproccesing pool with 6 processes
# 21:16 bilby INFO    : Starting to sample
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 likelihood = Likelihood( "12c_pg.azr", nprocs=nprocs)
# ----> 3 result = bilby.run_sampler( likelihood=likelihood, priors=priors, sampler="ptemcee", outdir="results/bilby/", label="samples", npool=nprocs, pos0=p0, nsteps=nsteps, nthin=nthin, nwalkers=nw, ntemps=nt)
#
# File ~/miniconda3/lib/python3.11/site-packages/bilby/core/sampler/__init__.py:234, in run_sampler(likelihood, priors, label, outdir, sampler, use_ratio, injection_parameters, conversion_function, plot, default_priors_file, clean, meta_data, save, gzip, result_class, npool, **kwargs)
#     232     result = sampler._run_test()
#     233 else:
# --> 234     result = sampler.run_sampler()
#     235 end_time = datetime.datetime.now()
#     237 # Some samplers calculate the sampling time internally
#
# File ~/miniconda3/lib/python3.11/site-packages/bilby/core/sampler/base_sampler.py:97, in signal_wrapper.<locals>.wrapped(self, *args, **kwargs)
#      91     _set = False
#      92     logger.debug(
#      93         "Setting signal attributes unavailable on this system. "
#      94         "This is likely the case if you are running on a Windows machine "
#      95         "and can be safely ignored."
#      96     )
# ---> 97 output = method(self, *args, **kwargs)
#      98 if _set:
#      99     signal.signal(signal.SIGTERM, old_term)
#
# File ~/miniconda3/lib/python3.11/site-packages/bilby/core/sampler/ptemcee.py:515, in Ptemcee.run_sampler(self)
#     512 logger.info("Starting to sample")
#     514 while True:
# --> 515     for (pos0, log_posterior, log_likelihood) in sampler.sample(
#     516         self.pos0,
#     517         storechain=False,
#     518         iterations=self.convergence_inputs.niterations_per_check,
#     519         **self.sampler_function_kwargs,
#     520     ):
#     521         pos0[:, :, self._periodic] = (
#     522             np.mod(
#     523                 pos0[:, :, self._periodic] - self._minima[self._periodic],
#    (...)
#     526             + self._minima[self._periodic]
#     527         )
#     529     if self.iteration == self.chain_array.shape[1]:
#
# File ~/miniconda3/lib/python3.11/site-packages/ptemcee/sampler.py:355, in Sampler.sample(self, p0, iterations, thin, storechain, adapt, swap_ratios)
#     352     logpost = self._logposterior0
#     354 if (logpost == -np.inf).any():
# --> 355     raise ValueError('Attempting to start with samples outside posterior support.')
#     357 # Expand the chain in advance of the iterations
#     358 if storechain:
#
# ValueError: Attempting to start with samples outside posterior support.
